# %%
import pandas as pd
import json
from pathlib import Path 
from dataclasses import dataclass, field, asdict

# %%
_ls = []

with open("indoor_playgrounds.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
    _ls = data

# %%
from src.core.event import Event
from src.utils.file_utils import save_to_json
event_obj_ls = []
for event_dict in _ls:
    event_obj = Event.from_dict(event_dict)
    event_obj.full_address, event_obj.latitude, event_obj.longitude = event_obj.get_address_n_coord()
    event_obj.images = event_obj.get_images(Path("data/evergreen/indoor_playgrounds/images"))
    event_obj_ls += [event_obj]
    

events_dict_ls_ = [asdict(event) for event in event_obj_ls]
save_to_json(events_dict_ls_, Path('data/evergreen/indoor_playgrounds/indoor_playgrounds.json'),2)
# Out:
# │ │ │ [custom_search.search_valid_url] Search failed: 'items'
# │ │ │ [custom_search.search_valid_url] Search failed: 'items'
# │ │ │ [custom_search.search_images] No images found from any source. Query: PIP’s PLAYbox: Bright & Airy Play at Esplanade by Esplanade – Theatres on the Bay
# │ │ │ [custom_search.search_valid_url] Search failed: 'items'
# │ │ │ [custom_search.search_images] No images found from any source. Query: Thoughtful Play Space within Tampines Library by Jolly Jungle
# │ │ │ [custom_search.search_images] No images found from any source. Query: Bright, Pastel-Coloured Playground with Eight Stations by SMIGY
# True
